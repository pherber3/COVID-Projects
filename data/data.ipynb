# %%
import pandas as pd

# %%
#https://www.edweek.org/ew/section/multimedia/map-coronavirus-and-school-closures.html
xls = pd.ExcelFile('coronavirus-school-closures-data.xlsx')
state_closures = pd.read_excel(xls, 'States', header=1)
district_closures = pd.read_excel(xls, 'Districts', header=1)

# %%
# Out:
#           State State Abbreviation            City  \
# 0    California                CA          Rocklin
# 1    California                CA       Sacramento
# 2    California                CA   Warner Springs
# 3    California                CA    Scotts Valley
# 4    California                CA    Valley Center
# ..          ...                ...             ...
# 501     Wyoming                WY           Ethete
# 502     Wyoming                WY        Clearmont
# 503     Wyoming                WY       Ranchester
# 504     Wyoming                WY         Sheridan
# 505     Wyoming                WY          Jackson
#
#                                    District Name  Number of Schools  \
# 0                                Rocklin Unified               21.0
# 1                                Natomas Unified               20.0
# 2                        Warner Unified District                6.0
# 3                          Scotts Valley Unified                4.0
# ...
