# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('COVID-19 Data-611b94bd6d09.json',scope)
client = gspread.authorize(creds)
import pandas as pd

# %%
sheet1 = client.open('COVID-19 Data').get_worksheet(0)
sheet2 = client.open('COVID-19 Data').get_worksheet(1)
sheet3 = client.open('COVID-19 Data').get_worksheet(2)
sheet4 = client.open('COVID-19 Data').get_worksheet(3)
sheet5 = client.open('COVID-19 Data').get_worksheet(4)
sheet6 = client.open('COVID-19 Data').get_worksheet(5)
sheet7 = client.open('COVID-19 Data').get_worksheet(6)
sheet8 = client.open('COVID-19 Data').get_worksheet(7)
sheet9 = client.open('COVID-19 Data').get_worksheet(8)
sheet10 = client.open('COVID-19 Data').get_worksheet(9)
sheet11 = client.open('COVID-19 Data').get_worksheet(10)
sheet12 = client.open('COVID-19 Data').get_worksheet(11)


states_current = pd.DataFrame(data=sheet1.get_all_records())
states_daily = pd.DataFrame(data=sheet2.get_all_records())
us_current = pd.DataFrame(data=sheet3.get_all_records())
us_daily = pd.DataFrame(data=sheet4.get_all_records())
time_series_recovered = pd.DataFrame(data=sheet5.get_all_records())
time_series_confirmed = pd.DataFrame(data=sheet6.get_all_records())
time_series_deaths = pd.DataFrame(data=sheet7.get_all_records())
open_line_list = pd.DataFrame(data=sheet8.get_all_records())
line_list = pd.DataFrame(data=sheet9.get_all_records())
jhu_data = pd.DataFrame(data=sheet10.get_all_records())
state_school_closures = pd.DataFrame(data=sheet11.get_all_records())
district_school_closures = pd.DataFrame(data=sheet12.get_all_records())

# %%
# Out:
# [{'': 'NCES ID'},
#  {'': 600013},
#  {'': 600036},
#  {'': 600042},
#  {'': 600043},
#  {'': 600069},
#  {'': 600082},
#  {'': 600095},
#  {'': 600096},
#  {'': 600135},
#  {'': 600137},
#  {'': 600143},
#  {'': 600148},
#  {'': 601327},
#  {'': 601332},
#  {'': 601343},
#  {'': 601354},
#  {'': 601358},
#  {'': 601366},
#  {'': 601372},
#  {'': 601381},
#  {'': 601389},
#  {'': 601391},
#  {'': 601398},
#  {'': 601400},
#  {'': 601401},
#  {'': 601421},
#  {'': 601422},
#  {'': 601426},
#  {'': 601680},
#  {'': 602100},
#  {'': 602250},
#  {'': 602310},
#  {'': 603060},
#  {'': 603480},
#  {'': 604800},
#  {'': 605240},
#  {'': 605640},
#  {'': 605700},
#  {'': 606030},
#  {'': 606270},
#  {'': 606810},
#  {'': 607140},
#  {'': 607170},
#  {'': 607200},
#  {'': 607230},
#  {'': 607900},
#  {'': 608610},
#  {'': 609300},
#  {'': 609640},
#  {'': 609870},
#  {'': 610290},
#  {'': 610620},
#  {'': 610710},
#  {'': 611490},
#  {'': 611820},
#  {'': 612070},
#  {'': 612330},
# ...
